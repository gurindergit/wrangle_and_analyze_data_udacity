# %% [markdown]
# ## We Rate Dogs - Twitter Page Analyzation
# The following insights and visualizations were gathered from the dataset:

# %% [markdown]
# ### Insight
# - The three most popular dog breeds are **golden_retriever**, **labrador_retrieve** and **pembroke**. **golden_retriever** is the most popular dog breed with more than 150 occurances in the data. <br/>
# (Shown through the Visualization below.)

# %% [markdown]
# ![dogs.png](attachment:dogs.png)

# %% [markdown]
# ### Insight
# - **favourites** have a significantly more rise in the given timespan than the **rewteets**. But looking at the relation of both trends, it is safe to day that both are still positively correlated.
# - Starting from almost a zero scale in 2015, the favorites reached more than 35000 in 2017. With this upward trend, it is clear that the popularity of this page is gradually increasing over the years. <br/>
# (Insights shown through the Visualization below.)

# %% [markdown]
# ![retweets.png](attachment:retweets.png)
